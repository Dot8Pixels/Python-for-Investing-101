# %%
from pandas_datareader import data as pdr
import pandas as pd
import mplfinance as mpf
import yfinance as yf
yf.pdr_override()

# %%
PTT = pdr.get_data_yahoo("PTT.BK", start = "2019-01-01", end = "2021-07-01")
PTT
# Out:
# [*********************100%***********************]  1 of 1 completed
#              Open   High    Low  Close  Adj Close    Volume
# Date
# 2019-01-02  46.25  46.75  46.25  46.25  40.698715  30481900
# 2019-01-03  46.50  47.00  45.25  45.50  40.038738  53438400
# 2019-01-04  45.50  47.00  45.25  46.75  41.138699  60708300
# 2019-01-07  47.25  48.75  47.25  48.00  42.238667  86356300
# 2019-01-08  48.25  48.75  47.75  48.00  42.238667  50671500
# ...           ...    ...    ...    ...        ...       ...
# 2021-06-24  40.00  40.25  39.50  40.00  38.814816  43225600
# 2021-06-25  40.00  40.50  39.75  39.75  38.572220  41171000
# 2021-06-28  39.75  40.00  39.50  39.75  38.572220  30819800
# 2021-06-29  39.75  40.00  39.50  39.50  38.329628  38739300
# 2021-06-30  39.50  39.75  39.25  39.25  38.087036  41053800
#
# [605 rows x 6 columns]

# %%
mpf.plot(PTT)
# Out:
# C:\Users\gunsr\Anaconda3\envs\investic\lib\site-packages\mplfinance\_arg_validators.py:35: UserWarning:
#
# ...
#
#    WARNING: YOU ARE PLOTTING SO MUCH DATA THAT IT MAY NOT BE
#             POSSIBLE TO SEE DETAILS (Candles, Ohlc-Bars, Etc.)
#    For more information see:
#    - https://github.com/matplotlib/mplfinance/wiki/Plotting-Too-Much-Data
#
#    TO SILENCE THIS WARNING, set `type='line'` in `mpf.plot()`
#    OR set kwarg `warn_too_much_data=N` where N is an integer
#    LARGER than the number of data points you want to plot.
#
# ...
#   warnings.warn('\n\n ================================================================= '+

# %%
PTT.Close.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
mpf.plot(PTT.loc['2021'], type = 'candle')

# %%
mpf.plot(PTT.loc['2019-01' : '2019-04'], type='candle', figsize=(10,6), mav=10)

# %%
mpf.plot(PTT.loc['2019'], type='candle', figsize=(10,6), mav=(10, 20, 50))

# %%
data = PTT.loc['2019-01']

# %%
kwargs = dict(mav=(6,10), volume=True, type='candle', show_nontrading=False)

# %%
mpf.plot(data, **kwargs, style='charles')

# %%
mpf.available_styles()
# Out:
# ['binance',
#  'blueskies',
#  'brasil',
#  'charles',
#  'checkers',
#  'classic',
#  'default',
#  'ibd',
#  'kenan',
#  'mike',
#  'nightclouds',
#  'sas',
#  'starsandstripes',
#  'yahoo']
