# %% [markdown]
# # Concatenate, Merge, Join

# %%
# !pip install pandas
# !pip install pandas_datareader
# !pip install yfinance
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (1.3.5)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (2018.9)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (1.19.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# Requirement already satisfied: pandas_datareader in /usr/local/lib/python3.7/dist-packages (0.9.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from pandas_datareader) (2.27.1)
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (from pandas_datareader) (4.7.1)
# Requirement already satisfied: pandas>=0.23 in /usr/local/lib/python3.7/dist-packages (from pandas_datareader) (1.3.5)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.23->pandas_datareader) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.23->pandas_datareader) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.23->pandas_datareader) (1.19.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.23->pandas_datareader) (1.15.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pandas_datareader) (2.10)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pandas_datareader) (2.0.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pandas_datareader) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pandas_datareader) (1.24.3)
# Requirement already satisfied: yfinance in /usr/local/lib/python3.7/dist-packages (0.1.70)
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.3.5)
# Requirement already satisfied: requests>=2.26 in /usr/local/lib/python3.7/dist-packages (from yfinance) (2.27.1)
# Requirement already satisfied: lxml>=4.5.1 in /usr/local/lib/python3.7/dist-packages (from yfinance) (4.7.1)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.19.5)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from yfinance) (0.0.10)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yfinance) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yfinance) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.24.0->yfinance) (1.15.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (1.24.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.0.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2021.10.8)

# %%
import pandas as pd
from pandas_datareader import data as web
import yfinance as yf

# %%
yf.pdr_override()

# %%
start = '2015-01-01'
end = '2021-01-01'

# %%
spy = web.get_data_yahoo('^GSPC', start=start, end=end)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
spy_price = spy['Adj Close']

# %%
spy_price
# Out:
# Date
# 2015-01-02    2058.199951
# 2015-01-05    2020.579956
# 2015-01-06    2002.609985
# 2015-01-07    2025.900024
# 2015-01-08    2062.139893
#                  ...
# 2020-12-24    3703.060059
# 2020-12-28    3735.360107
# 2020-12-29    3727.040039
# 2020-12-30    3732.040039
# 2020-12-31    3756.070068
# Name: Adj Close, Length: 1511, dtype: float64

# %%
nflx = web.get_data_yahoo('NFLX', start=start, end=end)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
nflx_price = nflx['Adj Close']

# %% [markdown]
# ## Concatenate

# %%
df = pd.concat([spy_price, nflx_price], join='inner', axis=1, keys=['SPY', 'Netflix'])

# %%
df
# Out:
#                     SPY     Netflix
# Date
# 2015-01-02  2058.199951   49.848572
# 2015-01-05  2020.579956   47.311428
# 2015-01-06  2002.609985   46.501431
# 2015-01-07  2025.900024   46.742859
# 2015-01-08  2062.139893   47.779999
# ...                 ...         ...
# 2020-12-24  3703.060059  513.969971
# 2020-12-28  3735.360107  519.119995
# 2020-12-29  3727.040039  530.869995
# 2020-12-30  3732.040039  524.590027
# 2020-12-31  3756.070068  540.729980
#
# [1511 rows x 2 columns]

# %%
nvda = web.get_data_yahoo('NVDA', start=start, end=end)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
nvda['Nvidia'] = nvda['Adj Close']
nvda_price = nvda['Nvidia']

# %% [markdown]
# ## Merge

# %%
df_stock = df.merge(nvda_price, how='left', on='Date')

# %%
df_stock
# Out:
#                     SPY     Netflix      Nvidia
# Date
# 2015-01-02  2058.199951   49.848572    4.839471
# 2015-01-05  2020.579956   47.311428    4.757731
# 2015-01-06  2002.609985   46.501431    4.613484
# 2015-01-07  2025.900024   46.742859    4.601463
# 2015-01-08  2062.139893   47.779999    4.774560
# ...                 ...         ...         ...
# 2020-12-24  3703.060059  513.969971  129.824097
# 2020-12-28  3735.360107  519.119995  128.887421
# 2020-12-29  3727.040039  530.869995  129.319565
# 2020-12-30  3732.040039  524.590027  131.342789
# 2020-12-31  3756.070068  540.729980  130.436081
#
# [1511 rows x 3 columns]

# %%
df_stock.isnull().sum()
# Out:
# SPY        0
# Netflix    0
# Nvidia     0
# dtype: int64

# %%
sq = web.get_data_yahoo('SQ', start=start, end=end)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
sq
# Out:
#                   Open        High  ...   Adj Close    Volume
# Date                                ...
# 2015-11-19   11.200000   14.780000  ...   13.070000  47466100
# 2015-11-20   13.920000   14.050000  ...   12.850000  16550300
# 2015-11-23   13.000000   13.150000  ...   12.120000   5172200
# 2015-11-24   12.000000   12.230000  ...   12.020000   4714700
# 2015-11-25   12.120000   12.400000  ...   11.900000   3583400
# ...                ...         ...  ...         ...       ...
# 2020-12-24  234.229996  236.000000  ...  228.279999   8411200
# 2020-12-28  232.380005  232.949997  ...  223.339996  11640000
# 2020-12-29  223.880005  224.589996  ...  214.000000  15453100
# 2020-12-30  215.940002  221.509995  ...  221.039993   9837000
# 2020-12-31  217.710007  219.449997  ...  217.639999   6872400
#
# [1288 rows x 6 columns]

# %%
sq['Square'] = sq['Adj Close']
sq_price = sq['Square']

# %% [markdown]
# ### Right Join

# %%
df_right = df_stock.merge(sq_price, how='right', on='Date')

# %%
df_right
# Out:
#                     SPY     Netflix      Nvidia      Square
# Date
# 2015-11-19  2081.239990  120.220001    7.605675   13.070000
# 2015-11-20  2089.169922  123.839996    7.671661   12.850000
# 2015-11-23  2086.590088  125.029999    7.556795   12.120000
# 2015-11-24  2089.139893  123.309998    7.617896   12.020000
# 2015-11-25  2088.870117  124.160004    7.608118   11.900000
# ...                 ...         ...         ...         ...
# 2020-12-24  3703.060059  513.969971  129.824097  228.279999
# 2020-12-28  3735.360107  519.119995  128.887421  223.339996
# 2020-12-29  3727.040039  530.869995  129.319565  214.000000
# 2020-12-30  3732.040039  524.590027  131.342789  221.039993
# 2020-12-31  3756.070068  540.729980  130.436081  217.639999
#
# [1288 rows x 4 columns]

# %% [markdown]
# ### Left Join

# %%
df_left = df_stock.merge(sq_price, how='left', on='Date')

# %%
df_left
# Out:
#                     SPY     Netflix      Nvidia      Square
# Date
# 2015-01-02  2058.199951   49.848572    4.839471         NaN
# 2015-01-05  2020.579956   47.311428    4.757731         NaN
# 2015-01-06  2002.609985   46.501431    4.613484         NaN
# 2015-01-07  2025.900024   46.742859    4.601463         NaN
# 2015-01-08  2062.139893   47.779999    4.774560         NaN
# ...                 ...         ...         ...         ...
# 2020-12-24  3703.060059  513.969971  129.824097  228.279999
# 2020-12-28  3735.360107  519.119995  128.887421  223.339996
# 2020-12-29  3727.040039  530.869995  129.319565  214.000000
# 2020-12-30  3732.040039  524.590027  131.342789  221.039993
# 2020-12-31  3756.070068  540.729980  130.436081  217.639999
#
# [1511 rows x 4 columns]

# %%
df_left.isnull().sum()
# Out:
# SPY          0
# Netflix      0
# Nvidia       0
# Square     223
# dtype: int64

# %% [markdown]
# ## Fill or Drop

# %%
df_left.fillna(method='ffill')
# Out:
#                     SPY     Netflix      Nvidia      Square
# Date
# 2015-01-02  2058.199951   49.848572    4.839471         NaN
# 2015-01-05  2020.579956   47.311428    4.757731         NaN
# 2015-01-06  2002.609985   46.501431    4.613484         NaN
# 2015-01-07  2025.900024   46.742859    4.601463         NaN
# 2015-01-08  2062.139893   47.779999    4.774560         NaN
# ...                 ...         ...         ...         ...
# 2020-12-24  3703.060059  513.969971  129.824097  228.279999
# 2020-12-28  3735.360107  519.119995  128.887421  223.339996
# 2020-12-29  3727.040039  530.869995  129.319565  214.000000
# 2020-12-30  3732.040039  524.590027  131.342789  221.039993
# 2020-12-31  3756.070068  540.729980  130.436081  217.639999
#
# [1511 rows x 4 columns]

# %%
df_left.fillna(method='bfill')
# Out:
#                     SPY     Netflix      Nvidia      Square
# Date
# 2015-01-02  2058.199951   49.848572    4.839471   13.070000
# 2015-01-05  2020.579956   47.311428    4.757731   13.070000
# 2015-01-06  2002.609985   46.501431    4.613484   13.070000
# 2015-01-07  2025.900024   46.742859    4.601463   13.070000
# 2015-01-08  2062.139893   47.779999    4.774560   13.070000
# ...                 ...         ...         ...         ...
# 2020-12-24  3703.060059  513.969971  129.824097  228.279999
# 2020-12-28  3735.360107  519.119995  128.887421  223.339996
# 2020-12-29  3727.040039  530.869995  129.319565  214.000000
# 2020-12-30  3732.040039  524.590027  131.342789  221.039993
# 2020-12-31  3756.070068  540.729980  130.436081  217.639999
#
# [1511 rows x 4 columns]

# %%
df_left.dropna()
# Out:
#                     SPY     Netflix      Nvidia      Square
# Date
# 2015-11-19  2081.239990  120.220001    7.605675   13.070000
# 2015-11-20  2089.169922  123.839996    7.671661   12.850000
# 2015-11-23  2086.590088  125.029999    7.556795   12.120000
# 2015-11-24  2089.139893  123.309998    7.617896   12.020000
# 2015-11-25  2088.870117  124.160004    7.608118   11.900000
# ...                 ...         ...         ...         ...
# 2020-12-24  3703.060059  513.969971  129.824097  228.279999
# 2020-12-28  3735.360107  519.119995  128.887421  223.339996
# 2020-12-29  3727.040039  530.869995  129.319565  214.000000
# 2020-12-30  3732.040039  524.590027  131.342789  221.039993
# 2020-12-31  3756.070068  540.729980  130.436081  217.639999
#
# [1288 rows x 4 columns]
