# %%
import ccxt
import pandas as pd
from datetime import datetime
import sys

# %%
sys.path.append(r'C:\Users\gunsr\Desktop\Programming\Git Remote\Investic\Python-for-Investing-101\Global_Config')
import api_key

# %%
bn_key = api_key.binance_api_key
bn_secret = api_key.binance_api_secret

# %%
# Pull data from FTX exchange

ftx = ccxt.ftx()
get_ftx_market = ftx.load_markets()
ftx.markets['DOGE/USDT']
# Out:
# {'id': 'DOGE/USDT',
#  'symbol': 'DOGE/USDT',
#  'base': 'DOGE',
#  'quote': 'USDT',
#  'baseId': 'DOGE',
#  'quoteId': 'USDT',
#  'active': True,
#  'type': 'spot',
#  'linear': None,
#  'inverse': None,
#  'spot': True,
#  'swap': False,
#  'future': False,
#  'option': False,
#  'margin': True,
#  'contract': False,
#  'contractSize': 1.0,
#  'expiry': None,
#  'expiryDatetime': None,
#  'optionType': None,
#  'strike': None,
#  'settle': None,
#  'settleId': None,
#  'precision': {'amount': 1.0, 'price': 5e-07},
#  'limits': {'leverage': {'min': 1.0, 'max': 20.0},
#   'amount': {'min': 1.0, 'max': None},
#   'price': {'min': None, 'max': None},
#   'cost': {'min': None, 'max': None}},
#  'info': {'name': 'DOGE/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': '5e-7',
#   'sizeIncrement': '1.0',
#   'minProvideSize': '1.0',
#   'last': '0.134642',
#   'bid': '0.1347465',
#   'ask': '0.1348305',
#   'price': '0.1347465',
#   'type': 'spot',
# ...

# %%
# Pull data from Binance exchange

binance = ccxt.binance({
    'apiKey' : bn_key,
    'secret' : bn_secret 
})

# %%
get_market = binance.load_markets()

# %%
binance.markets['BTC/USDT']
# Out:
# {'id': 'BTCUSDT',
#  'symbol': 'BTC/USDT',
#  'base': 'BTC',
#  'quote': 'USDT',
#  'baseId': 'BTC',
#  'quoteId': 'USDT',
#  'active': True,
#  'type': 'spot',
#  'linear': None,
#  'inverse': None,
#  'spot': True,
#  'swap': False,
#  'future': False,
#  'option': False,
#  'margin': True,
#  'contract': False,
#  'contractSize': None,
#  'expiry': None,
#  'expiryDatetime': None,
#  'optionType': None,
#  'strike': None,
#  'settle': None,
#  'settleId': None,
#  'precision': {'amount': 5, 'price': 2, 'base': 8, 'quote': 8},
#  'limits': {'leverage': {'min': None, 'max': None},
#   'amount': {'min': 1e-05, 'max': 9000.0},
#   'price': {'min': 0.01, 'max': 1000000.0},
#   'cost': {'min': 10.0, 'max': None},
#   'market': {'min': 0.0, 'max': 146.79502738}},
#  'info': {'symbol': 'BTCUSDT',
#   'status': 'TRADING',
#   'baseAsset': 'BTC',
#   'baseAssetPrecision': '8',
#   'quoteAsset': 'USDT',
#   'quotePrecision': '8',
#   'quoteAssetPrecision': '8',
# ...

# %%
bars = binance.fetch_ohlcv('BTC/USDT', timeframe='1h', limit=100)
bars
# Out:
# [[1649372400000, 43629.72, 43750.0, 43425.22, 43444.19, 1084.24711],
#  [1649376000000, 43444.2, 43527.36, 43305.57, 43327.46, 1004.29322],
#  [1649379600000, 43327.47, 43647.92, 43310.0, 43607.61, 1021.10737],
#  [1649383200000, 43607.61, 43694.15, 43566.38, 43615.63, 772.47903],
#  [1649386800000, 43615.63, 43691.83, 43550.0, 43605.96, 547.45765],
#  [1649390400000, 43605.95, 43659.83, 43491.46, 43543.02, 509.97862],
#  [1649394000000, 43543.03, 43678.2, 43476.97, 43654.3, 659.14366],
#  [1649397600000, 43654.3, 43672.53, 43484.28, 43573.45, 1187.43884],
#  [1649401200000, 43573.45, 43780.32, 43416.74, 43763.52, 1556.4029],
#  [1649404800000, 43763.53, 43970.62, 43650.0, 43700.33, 2334.89149],
#  [1649408400000, 43700.33, 43772.45, 43499.83, 43588.73, 1233.32916],
#  [1649412000000, 43588.72, 43621.85, 43500.1, 43558.51, 887.95801],
#  [1649415600000, 43558.51, 43561.37, 43260.76, 43298.79, 1880.17355],
#  [1649419200000, 43298.79, 43417.96, 43079.05, 43151.75, 1713.44905],
# ...

# %%
df = pd.DataFrame(bars, columns=['timestamp', 'open', 'high', 'low', 'close', 'volume'])
df
# Out:
#         timestamp      open      high       low     close      volume
# 0   1649372400000  43629.72  43750.00  43425.22  43444.19  1084.24711
# 1   1649376000000  43444.20  43527.36  43305.57  43327.46  1004.29322
# 2   1649379600000  43327.47  43647.92  43310.00  43607.61  1021.10737
# 3   1649383200000  43607.61  43694.15  43566.38  43615.63   772.47903
# 4   1649386800000  43615.63  43691.83  43550.00  43605.96   547.45765
# ..            ...       ...       ...       ...       ...         ...
# 95  1649714400000  39395.29  39978.62  39200.00  39766.39  3367.38574
# 96  1649718000000  39766.39  39840.39  39372.35  39530.45  2173.79856
# 97  1649721600000  39530.45  39852.95  39357.64  39544.31  3026.11925
# 98  1649725200000  39544.32  39727.80  39408.16  39504.54  2077.08447
# 99  1649728800000  39504.54  39550.48  39290.00  39473.00  1698.82863
#
# [100 rows x 6 columns]

# %%
df['timestamp'] = pd.to_datetime(df['timestamp'], unit='ms')
df
# Out:
#              timestamp      open      high       low     close      volume
# 0  2022-04-07 23:00:00  43629.72  43750.00  43425.22  43444.19  1084.24711
# 1  2022-04-08 00:00:00  43444.20  43527.36  43305.57  43327.46  1004.29322
# 2  2022-04-08 01:00:00  43327.47  43647.92  43310.00  43607.61  1021.10737
# 3  2022-04-08 02:00:00  43607.61  43694.15  43566.38  43615.63   772.47903
# 4  2022-04-08 03:00:00  43615.63  43691.83  43550.00  43605.96   547.45765
# ..                 ...       ...       ...       ...       ...         ...
# 95 2022-04-11 22:00:00  39395.29  39978.62  39200.00  39766.39  3367.38574
# 96 2022-04-11 23:00:00  39766.39  39840.39  39372.35  39530.45  2173.79856
# 97 2022-04-12 00:00:00  39530.45  39852.95  39357.64  39544.31  3026.11925
# 98 2022-04-12 01:00:00  39544.32  39727.80  39408.16  39504.54  2077.08447
# 99 2022-04-12 02:00:00  39504.54  39550.48  39290.00  39473.00  1698.82863
#
# [100 rows x 6 columns]

# %%
response = binance.create_order('DOGE/USDT', 'limit', 'buy', 10, 0.28) # Limit Order
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~\anaconda3\envs\investing\lib\site-packages\ccxt\base\exchange.py:647, in Exchange.fetch(self, url, method, headers, body)
#     <a href='file:///c%3A/Users/gunsr/anaconda3/envs/investing/lib/site-packages/ccxt/base/exchange.py?line=645'>646</a>     self.logger.debug("%s %s, Response: %s %s %s", method, url, http_status_code, headers, http_response)
# --> <a href='file:///c%3A/Users/gunsr/anaconda3/envs/investing/lib/site-packages/ccxt/base/exchange.py?line=646'>647</a>     response.raise_for_status()
#     <a href='file:///c%3A/Users/gunsr/anaconda3/envs/investing/lib/site-packages/ccxt/base/exchange.py?line=648'>649</a> except Timeout as e:
#
# File ~\anaconda3\envs\investing\lib\site-packages\requests\models.py:960, in Response.raise_for_status(self)
# ...

# %%
response = binance.create_order('DOGE/USDT', 'market', 'buy', 10) # Market Order
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~\anaconda3\envs\investing\lib\site-packages\ccxt\base\exchange.py:647, in Exchange.fetch(self, url, method, headers, body)
#     <a href='file:///c%3A/Users/gunsr/anaconda3/envs/investing/lib/site-packages/ccxt/base/exchange.py?line=645'>646</a>     self.logger.debug("%s %s, Response: %s %s %s", method, url, http_status_code, headers, http_response)
# --> <a href='file:///c%3A/Users/gunsr/anaconda3/envs/investing/lib/site-packages/ccxt/base/exchange.py?line=646'>647</a>     response.raise_for_status()
#     <a href='file:///c%3A/Users/gunsr/anaconda3/envs/investing/lib/site-packages/ccxt/base/exchange.py?line=648'>649</a> except Timeout as e:
#
# File ~\anaconda3\envs\investing\lib\site-packages\requests\models.py:960, in Response.raise_for_status(self)
# ...

# %%
my_open_orders = binance.fetch_open_orders('DOGE/USDT')
my_open_orders
# Out:
# []

# %%
# Check open orders list

ls_open_orders = pd.DataFrame(binance.fetch_open_orders('DOGE/USDT'))

# %%
ls_open_orders
# Out:
# Empty DataFrame
# Columns: []
# Index: []
