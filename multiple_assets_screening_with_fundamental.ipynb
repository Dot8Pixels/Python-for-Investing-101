# %%
import pandas as pd
import numpy as np

# %%
path = ".\data\stock-siamchart.xlsx"

# %%
df = pd.read_excel(path)

# %%
df
# Out:
#         Name    No.          Links Sign   Last  Chg%        Volume  Value (k)  \
# 0    Average    NaN            NaN  NaN  19.49  1.61  3.363165e+07  105048.26
# 1         2S    1.0  i | 1 | 2 | 3  NaN   6.85  2.24  1.073600e+06    7281.00
# 2     3K-BAT    2.0              i  NaN  68.25 -0.73  1.000000e+03      68.00
# 3        7UP    3.0  i | 1 | 2 | 3  NaN   1.61  2.55  2.758150e+08  440191.00
# 4          A    4.0  i | 1 | 2 | 3  NaN   4.96 -0.40  1.500000e+03       7.00
# ..       ...    ...            ...  ...    ...   ...           ...        ...
# 752      XPG  752.0  i | 1 | 2 | 3  NaN   3.98 -4.33  3.193370e+07  128129.00
# 753      YGG  753.0      i | 1 | 3  NaN  20.70 -1.90  6.996000e+05   14600.00
# 754    YUASA  754.0      i | 1 | 3  NaN  16.80  0.00  6.400000e+03     108.00
# 755      ZEN  755.0      i | 1 | 3  NaN  11.80 -0.84  1.912000e+05    2278.00
# 756     ZIGA  756.0  i | 1 | 2 | 3  NaN   5.05 -1.94  5.696200e+06   29052.00
#
# ...

# %%
# df[(df['P/E'] > 10) & 
# (df['P/E'] < 25) &
# (df['P/BV'] < 1)].sort_values(['P/E', 'ROE%'], ascending=[True, False]) # There is '-' in 'P/BV'

# %%
df[df['P/BV'] == '-']
# Out:
#        Name    No. Links Sign   Last  Chg%       Volume  Value (k)  MCap (M)  \
# 40      AMR   40.0     i  NaN   6.65  0.76    5043200.0    33595.0       0.0
# 164      CV  164.0     i  NaN   3.90  0.52  143669700.0   566762.0       0.0
# 351    MENA  351.0     i  NaN   2.04  0.00  136090200.0   286553.0       0.0
# 526  SECURE  526.0     i  NaN  24.70  0.41     681800.0    16816.0       0.0
# 559    SNNP  559.0     i  NaN  12.60 -2.33   10101300.0   128670.0       0.0
# 588   STECH  588.0     i  NaN   2.60  0.78    3758600.0     9764.0       0.0
#
#      P/E  ...   ROA%   ROE%   NPM%  Yield%  FFloat%  MG%  Magic1 Magic2  PEG  \
# 40   NaN  ...  18.84  54.93  10.90       -    37.78  NaN     NaN    NaN  NaN
# 164  NaN  ...   9.74  14.31   6.42       -    46.30  NaN     NaN    NaN  NaN
# 351  NaN  ...   6.00   6.58   7.25       -    41.30  NaN     NaN    NaN  NaN
# 526  NaN  ...   9.33  10.46   9.50       -    28.41  NaN     NaN    NaN  NaN
# ...

# %%
df = df.replace('-', np.nan)

# %%
df[df['P/BV'] == '-']
# Out:
# Empty DataFrame
# Columns: [Name, No., Links, Sign, Last, Chg%, Volume, Value (k), MCap (M), P/E, P/BV, D/E, DPS, EPS, ROA%, ROE%, NPM%, Yield%, FFloat%, MG%, Magic1, Magic2, PEG, CG]
# Index: []
#
# [0 rows x 24 columns]

# %%
df.dtypes
# Out:
# Name          object
# No.          float64
# Links         object
# Sign          object
# Last         float64
# Chg%         float64
# Volume       float64
# Value (k)    float64
# MCap (M)     float64
# P/E          float64
# P/BV          object
# D/E          float64
# DPS           object
# EPS          float64
# ROA%         float64
# ROE%         float64
# NPM%         float64
# Yield%        object
# FFloat%      float64
# MG%          float64
# Magic1       float64
# Magic2       float64
# PEG          float64
# CG           float64
# dtype: object

# %%
df['P/BV'] = df['P/BV'].astype(float)
df['Yield%'] = df['Yield%'].astype(float)

# %%
df.dtypes
# Out:
# Name          object
# No.          float64
# Links         object
# Sign          object
# Last         float64
# Chg%         float64
# Volume       float64
# Value (k)    float64
# MCap (M)     float64
# P/E          float64
# P/BV         float64
# D/E          float64
# DPS           object
# EPS          float64
# ROA%         float64
# ROE%         float64
# NPM%         float64
# Yield%       float64
# FFloat%      float64
# MG%          float64
# Magic1       float64
# Magic2       float64
# PEG          float64
# CG           float64
# dtype: object

# %%
df[(df['P/E'] > 10) & 
(df['P/E'] < 25) &
(df['P/BV'] < 1)].sort_values(['P/E', 'ROE%'], ascending=[True, False])
# Out:
#        Name    No.          Links Sign    Last   Chg%       Volume  Value (k)  \
# 159     CSC  159.0      i | 1 | 3  NaN   48.75  -0.51      46000.0     2247.0
# 597   SUSCO  597.0  i | 1 | 2 | 3  NaN    3.32   0.61    1608800.0     5345.0
# 96      BKI   96.0  i | 1 | 2 | 3  NaN  270.00  -0.37      17100.0     4623.0
# 349     MDX  349.0      i | 1 | 3  NaN    6.15   3.36    6655900.0    40450.0
# 79      BCP   79.0  i | 1 | 2 | 3  NaN   27.25   0.93   10457800.0   285228.0
# 223     GJS  223.0  i | 1 | 2 | 3  NaN    0.38  11.76  426575200.0   156050.0
# 672   TPIPL  672.0  i | 1 | 2 | 3  NaN    1.80   0.56   18306200.0    33085.0
# 253     IFS  253.0      i | 1 | 3  NaN    2.58   0.00     856100.0     2198.0
# 439    PMTA  439.0  i | 1 | 2 | 3  NaN   11.50   0.00      31700.0      366.0
# 688     TSE  688.0  i | 1 | 2 | 3  NaN    2.82   0.00    9285800.0    26121.0
# 296    KCAR  296.0  i | 1 | 2 | 3  NaN    8.55  -1.16      89000.0      761.0
# ...

# %%
df[(df['P/E'] > 5) &
(df['P/E'] < 20) & 
(df['Yield%'] > 5)].sort_values(['P/E', 'Yield%','ROE%'], 
ascending=[True, False, False])
# Out:
#        Name    No.          Links Sign   Last  Chg%      Volume  Value (k)  \
# 528    SENA  528.0      i | 1 | 3  NaN   3.96  0.00    810200.0     3198.0
# 43       AP   43.0  i | 1 | 2 | 3  NaN   8.40  0.60   5562200.0    46413.0
# 658   TNITY  658.0      i | 1 | 3  NaN   6.70  0.00    426300.0     2861.0
# 348     MCS  348.0  i | 1 | 2 | 3   XD  14.60  0.00   2778800.0    40395.0
# 598   SUTHA  598.0  i | 1 | 2 | 3  NaN   4.50 -1.75    110900.0      502.0
# ..      ...    ...            ...  ...    ...   ...         ...        ...
# 211  FSMART  211.0  i | 1 | 2 | 3  NaN  10.60 -2.75   4030000.0    42969.0
# 621   TEAMG  621.0  i | 1 | 2 | 3  NaN   2.42  3.42  10392200.0    25014.0
# 471   Q-CON  471.0      i | 1 | 3  NaN   5.20 -0.95    105500.0      553.0
# 742   WHAUP  742.0  i | 1 | 2 | 3  NaN   4.26  0.00   2832100.0    12037.0
# 365  MODERN  365.0  i | 1 | 2 | 3  NaN   3.56 -1.11    192600.0      688.0
#
# ...
